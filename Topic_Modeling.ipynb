# %%
import pandas as pd

import numpy as np


reviews_datasets = pd.read_csv("Reviews.csv", on_bad_lines='skip', quoting=3)

reviews_datasets = reviews_datasets.head(20000)

reviews_datasets.dropna()
# Out:
#        Id   ProductId          UserId                     ProfileName  \
# 0       1  B001E4KFG0  A3SGXH7AUHU8GW                      delmartian
# 1       2  B00813GRG4  A1D87F6ZCVE5NK                          dll pa
# 2       4  B000UA0QIQ  A395BORC6FGVXV                            Karl
# 3       9  B000E7L2R4  A1MZYO9TZK0BBI                        R. James
# 4      10  B00171APVA  A21BT40VZCCYT4                   Carol A. Reed
# ..    ...         ...             ...                             ...
# 596  2115  B00061EXBU   AHS5ZGN797CZG              "R. Etter ""Rho"""
# 597  2116  B00061EXBU  A2C6CB16OESI3D                     C. Fontenot
# 598  2118  B00061EXBU  A143VWWW5CGG2S  "Richard Lee ""What is Hip?"""
# 599  2123  B0017OV6LA  A3VP845SOWSCAI     "L. Ruth Sr. ""Sun Lover"""
# 600  2128  B004ET9OIW   A4P3BAGC9HE3H                  Tania Gonzalez
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                       1                       1      5  1303862400
# 1                       0                       0      1  1346976000
# 2                       3                       3      2  1307923200
# 3                       1                       1      5  1322006400
# 4                       0                       0      5  1351209600
# ..                    ...                     ...    ...         ...
# 596                     1                       1      5  1264982400
# 597                     0                       0      5  1327968000
# 598                     4                      12      5  1175040000
# 599                     0                       0      5  1277769600
# 600                     1                       1      5  1306972800
#
#                                   Summary  \
# 0                   Good Quality Dog Food
# 1                       Not as Advertised
# 2                          Cough Medicine
# 3                              Yay Barley
# 4                        Healthy Dog Food
# ..                                    ...
# 596                Cheaper from Penta.com
# 597  Much Cheaper through Penta's Website
# 598          To wash my record collection
# 599                       Awesome Candy!!
# 600     Super healthy and Baby loves them
#
#                                                   Text
# 0    I have bought several of the Vitality canned d...
# 1    "Product arrived labeled as Jumbo Salted Peanu...
# 2    If you are looking for the secret ingredient i...
# 3    Right now I'm mostly just sprouting this so my...
# 4    This is a very healthy dog food. Good for thei...
# ..                                                 ...
# 596  I too have begun to drink only Penta water unl...
# 597  You can purchase this for $35.00 including fre...
# 598  "I bought bottles of this stuff because of its...
# 599  I love this candy and ate it a lot as a kid. I...
# 600  Baby loves to feed herself and these are a gre...
#
# [601 rows x 10 columns]

# %%
reviews_datasets['Text'][350]
# Out:
# 'This tea is so helpful for congestion and it tastes great too.  Make sure you let it steep as long as the directions say.  It really seems to help you to feel better.'

# %%
from sklearn.feature_extraction.text import CountVectorizer



count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')

doc_term_matrix = count_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
CountVectorizer?

# %%
print(doc_term_matrix)
# Out:
#   (0, 121)	1
#   (0, 152)	1
#   (0, 309)	1
#   (0, 419)	1
#   (0, 829)	1
#   (0, 461)	1
#   (0, 843)	1
#   (0, 828)	2
#   (0, 626)	1
#   (0, 602)	1
#   (0, 658)	1
#   (0, 975)	1
#   (0, 101)	2
#   (0, 402)	1
#   (1, 828)	2
#   (1, 57)	1
#   (1, 905)	1
#   (1, 23)	1
#   (1, 972)	1
#   (1, 965)	1
#   (1, 1117)	1
#   (1, 1040)	1
#   (1, 1131)	1
#   (2, 461)	1
#   (2, 625)	1
#   :	:
#   (599, 955)	1
#   (599, 354)	1
#   (599, 1105)	1
#   (599, 628)	1
#   (599, 220)	1
#   (599, 198)	1
#   (600, 843)	1
#   (600, 470)	1
#   (600, 314)	1
#   (600, 127)	1
#   (600, 1100)	1
#   (600, 512)	1
#   (600, 732)	1
#   (600, 72)	1
#   (600, 633)	1
#   (600, 584)	1
#   (600, 67)	1
#   (600, 383)	1
#   (600, 388)	1
#   (600, 376)	1
#   (600, 71)	1
#   (600, 452)	1
#   (600, 386)	1
#   (600, 442)	1
#   (600, 531)	1

# %%
from sklearn.decomposition import LatentDirichletAllocation



LDA = LatentDirichletAllocation(n_components=5, random_state=42) # 5 topics

LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# print 10 random words
import random
for i in range(10):
    random_id = random.randint(0,len(count_vect.get_feature_names_out()))
    print(count_vect.get_feature_names_out()[random_id])
# Out:
# container
# rice
# candy
# coconut
# flavoring
# life
# crash
# cherry
# dish
# start

# %%
# print 10 random words
import random
for i in range(10):
    random_id = random.randint(0,len(count_vect.get_feature_names_out()))
    print(count_vect.get_feature_names_out()[random_id])
# Out:
# additives
# sauces
# bottles
# inexpensive
# leave
# finally
# anticipated
# add
# season
# glass

# %%
first_topic = LDA.components_[0] # topic 0

# %%
top_topic_words = first_topic.argsort()[-10:] # last 10 words

# %%
for i in top_topic_words:

    print(count_vect.get_feature_names_out()[i])
# Out:
# just
# flavor
# product
# great
# really
# good
# like
# taste
# br
# tea

# %%
for i,topic in enumerate(LDA.components_):

    print(f'Top 10 words for topic #{i+1}:')

    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])

    print('\n')
# Out:
# Top 10 words for topic #1:
# ['just', 'flavor', 'product', 'great', 'really', 'good', 'like', 'taste', 'br', 'tea']
#
#
# Top 10 words for topic #2:
# ['gift', 'bag', 'buy', 've', 'chips', 'amazon', 'product', 'price', 'great', 'good']
#
#
# Top 10 words for topic #3:
# ['love', 'flavor', 'dog', 'food', 'taste', 'mix', 'product', 'like', 'good', 'br']
#
#
# Top 10 words for topic #4:
# ['just', 'like', 'good', 'flavors', 'flavor', 'love', 'salt', 'great', 'br', 'chips']
#
#
# Top 10 words for topic #5:
# ['eat', 'amazon', 'love', 'buy', 'just', 'price', 'like', 'food', 'product', 'great']

# %%
topic_values = LDA.transform(doc_term_matrix)

topic_values.shape
# Out:
# (601, 5)

# %%
# adding topic number to original data

reviews_datasets['Topic'] = topic_values.argmax(axis=1)

# %%
reviews_datasets.head(3)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
# 2   4  B000UA0QIQ  A395BORC6FGVXV        Karl                     3
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       3      2  1307923200         Cough Medicine
#
#                                                 Text  Topic
# 0  I have bought several of the Vitality canned d...      2
# 1  "Product arrived labeled as Jumbo Salted Peanu...      4
# 2  If you are looking for the secret ingredient i...      0

# %%
import pandas as pd
import numpy as np
reviews_datasets = pd.read_csv("Reviews.csv", on_bad_lines='skip', quoting=3)
reviews_datasets = reviews_datasets.head(20000)
reviews_datasets.dropna()
# Out:
#        Id   ProductId          UserId                     ProfileName  \
# 0       1  B001E4KFG0  A3SGXH7AUHU8GW                      delmartian
# 1       2  B00813GRG4  A1D87F6ZCVE5NK                          dll pa
# 2       4  B000UA0QIQ  A395BORC6FGVXV                            Karl
# 3       9  B000E7L2R4  A1MZYO9TZK0BBI                        R. James
# 4      10  B00171APVA  A21BT40VZCCYT4                   Carol A. Reed
# ..    ...         ...             ...                             ...
# 596  2115  B00061EXBU   AHS5ZGN797CZG              "R. Etter ""Rho"""
# 597  2116  B00061EXBU  A2C6CB16OESI3D                     C. Fontenot
# 598  2118  B00061EXBU  A143VWWW5CGG2S  "Richard Lee ""What is Hip?"""
# 599  2123  B0017OV6LA  A3VP845SOWSCAI     "L. Ruth Sr. ""Sun Lover"""
# 600  2128  B004ET9OIW   A4P3BAGC9HE3H                  Tania Gonzalez
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                       1                       1      5  1303862400
# 1                       0                       0      1  1346976000
# 2                       3                       3      2  1307923200
# 3                       1                       1      5  1322006400
# 4                       0                       0      5  1351209600
# ..                    ...                     ...    ...         ...
# 596                     1                       1      5  1264982400
# 597                     0                       0      5  1327968000
# 598                     4                      12      5  1175040000
# 599                     0                       0      5  1277769600
# 600                     1                       1      5  1306972800
#
#                                   Summary  \
# 0                   Good Quality Dog Food
# 1                       Not as Advertised
# 2                          Cough Medicine
# 3                              Yay Barley
# 4                        Healthy Dog Food
# ..                                    ...
# 596                Cheaper from Penta.com
# 597  Much Cheaper through Penta's Website
# 598          To wash my record collection
# 599                       Awesome Candy!!
# 600     Super healthy and Baby loves them
#
#                                                   Text
# 0    I have bought several of the Vitality canned d...
# 1    "Product arrived labeled as Jumbo Salted Peanu...
# 2    If you are looking for the secret ingredient i...
# 3    Right now I'm mostly just sprouting this so my...
# 4    This is a very healthy dog food. Good for thei...
# ..                                                 ...
# 596  I too have begun to drink only Penta water unl...
# 597  You can purchase this for $35.00 including fre...
# 598  "I bought bottles of this stuff because of its...
# 599  I love this candy and ate it a lot as a kid. I...
# 600  Baby loves to feed herself and these are a gre...
#
# [601 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer



tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')

doc_term_matrix = tfidf_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=8, random_state=42) # 5 topics
nmf.fit(doc_term_matrix)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_nmf.py:1742: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# NMF(n_components=8, random_state=42)

# %%
import random



for i in range(10):

    random_id = random.randint(0,len(tfidf_vect.get_feature_names_out()))

    print(tfidf_vect.get_feature_names_out()[random_id])
# Out:
# teeth
# type
# potatoes
# dry
# safe
# eaten
# cold
# pups
# vegetables
# know

# %%
# getting top 10 words from topic 0

first_topic = nmf.components_[0]

top_topic_words = first_topic.argsort()[-10:]

# %%
for i in top_topic_words:

    print(tfidf_vect.get_feature_names_out()[i])
# Out:
# calorie
# pop
# regular
# low
# calories
# snack
# potato
# bag
# great
# chips

# %%
for i,topic in enumerate(nmf.components_):

    print(f'Top 10 words for topic #{i}:')

    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])

    print('\n')
# Out:
# Top 10 words for topic #0:
# ['calorie', 'pop', 'regular', 'low', 'calories', 'snack', 'potato', 'bag', 'great', 'chips']
#
#
# Top 10 words for topic #1:
# ['flavors', 'use', 'natural', 'order', 'ate', 'energy', 'kettle', 'buy', 'like', 'br']
#
#
# Top 10 words for topic #2:
# ['flavor', 'easy', 'maker', 'make', 'pancakes', 'best', 'pancake', 'waffles', 'waffle', 'mix']
#
#
# Top 10 words for topic #3:
# ['black', 'drinking', 'hot', 'iced', 'coffee', 'excellent', 'drink', 'flavor', 'great', 'tea']
#
#
# Top 10 words for topic #4:
# ['chips', 'favorite', 'tried', 'like', 'really', 'pepper', 'flavor', 'sea', 'vinegar', 'salt']
#
#
# Top 10 words for topic #5:
# ['dogs', 'favorite', 'year', 'old', 'cat', 'treats', 'eat', 'loves', 'dog', 'food']
#
#
# Top 10 words for topic #6:
# ['flavor', 'bags', 'just', 'delicious', 'amazon', 'popchips', 'try', 'variety', 'flavors', 'love']
#
#
# Top 10 words for topic #7:
# ['used', 'just', 'buy', 'really', 'great', 'price', 'like', 'taste', 'good', 'product']

# %%
topic_values = nmf.transform(doc_term_matrix)

reviews_datasets['Topic'] = topic_values.argmax(axis=1)

reviews_datasets.head()
# Out:
#    Id   ProductId          UserId    ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW     delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK         dll pa                     0
# 2   4  B000UA0QIQ  A395BORC6FGVXV           Karl                     3
# 3   9  B000E7L2R4  A1MZYO9TZK0BBI       R. James                     1
# 4  10  B00171APVA  A21BT40VZCCYT4  Carol A. Reed                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       3      2  1307923200         Cough Medicine
# 3                       1      5  1322006400             Yay Barley
# 4                       0      5  1351209600       Healthy Dog Food
#
#                                                 Text  Topic
# 0  I have bought several of the Vitality canned d...      7
# 1  "Product arrived labeled as Jumbo Salted Peanu...      7
# 2  If you are looking for the secret ingredient i...      7
# 3  Right now I'm mostly just sprouting this so my...      6
# 4  This is a very healthy dog food. Good for thei...      5
